# %%
print("hello hi")
# Out:
# hello hi

# %%
numbers = [10, 20, 30]

print(numbers)
# Out:
# [10, 20, 30]

# %%
print("How r u, i'm fyn, how r u ")
# Out:
# How r u, i'm fyn, how r u

# %%
numbers = [10, 20, 30]

numbers[1] = 60

print(numbers)
# Out:
# [10, 60, 30]

# %%
data = [10, "Hello", 3.5, True]

print(data)
# Out:
# [10, 'Hello', 3.5, True]

# %%
orders = ["ORD001", "ORD002", "ORD003", "ORD004", "ORD005"]
print(orders[0])
print(orders[-4])
# Out:
# ORD001
# ORD002

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[1:])

print(numbers[:4])
# Out:
# [20, 30, 40, 50]
# [10, 20, 30, 40]

# %%
numbers = [10, 20, 30, 40, 50,60]
print(numbers[::2])
# Out:
# [10, 30, 50]

# %%
numbers = (10, 20, 30, 40, 50)
first, *middle, last = numbers
print(f"First: {first}, Middle: {middle}, Last: {last}")
# Out:
# First: 10, Middle: [20, 30, 40], Last: 50

# %%
numbers = {10, 20, 30}

names = {"Rahul", "Priya", "Sneha"}
data = {(10, 20), (30, 40)}

# %%
set_a = {1, 2, 3, 6, 7}
set_b = {3, 4, 5, 6, 7}

print(set_a | set_b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[1:])
print(numbers[:4])

print(numbers[::2])
print(numbers[::-2])
# Out:
# [20, 30, 40, 50]
# [10, 20, 30, 40]
# [10, 30, 50]
# [50, 30, 10]

# %%
scores = [55,72,68,90,45,83,76,61,88,70]

print(scores[:4])
print(scores[-3:])
print(scores[3:8])
print(scores[::-1])

print(scores[::3])
# Out:
# [55, 72, 68, 90]
# [61, 88, 70]
# [90, 45, 83, 76, 61]
# [70, 88, 61, 76, 83, 45, 90, 68, 72, 55]
# [55, 90, 76, 70]

# %%
employee = ["Rahul","Analyst",45000]

employee[2] = 60000

print(employee)
# Out:
# ['Rahul', 'Analyst', 60000]

# %%
original = [45000, 62000, 38000]
backup = original

print("Before changing backup:")
print("original =", original)
print("backup   =", backup)

backup[0] = 99999

print("\n....................\n")

print("After changing backup:")
print("original =", original)
print("backup   =", backup)

backup = original.copy()
# Out:
# Before changing backup:
# original = [45000, 62000, 38000]
# backup   = [45000, 62000, 38000]
#
# ....................
#
# After changing backup:
# original = [99999, 62000, 38000]
# backup   = [99999, 62000, 38000]

# %%
original = [45000, 62000, 38000]

backup = original.copy()
print("Before changing backup:")
print("original =", original)
print("backup   =", backup)

backup[0] = 99999


print("After changing backup:")
print("original =", original)
print("backup   =", backup)
# Out:
# Before changing backup:
# original = [45000, 62000, 38000]
# backup   = [45000, 62000, 38000]
# After changing backup:
# original = [45000, 62000, 38000]
# backup   = [99999, 62000, 38000]

# %%
numbers = [10, 20]

numbers.append(40)

print(numbers)
# Out:
# [10, 20, 40]

# %%
numbers = [10, 20, 30]

numbers.insert(1, 15)

print(numbers)
# Out:
# [10, 15, 20, 30]

# %%
a = [1, 2]

a.extend([3, 4])

print(a)
# Out:
# [1, 2, 3, 4]

# %%
numbers = [10, 20, 30]

numbers.remove(20)

print(numbers)
# Out:
# [10, 30]

# %%
numbers = [10, 20, 30]

numbers.pop()

print(numbers)
# Out:
# [10, 20]

# %%
numbers = [10, 20, 30]

numbers.pop(1)

print(numbers)
# Out:
# [10, 30]

# %%
numbers = [40, 10, 30, 20]

numbers.sort()

print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
numbers = [40, 10, 30, 20]

numbers.sort(reverse=True)

print(numbers)
# Out:
# [40, 30, 20, 10]

# %%
numbers = [10, 20, 30, 40]

numbers.reverse()

print(numbers)
# Out:
# [40, 30, 20, 10]

# %%
numbers = [10, 20, 30]

backup = numbers.copy()

print("numbers =", numbers)
print("backup =", backup)
# Out:
# numbers = [10, 20, 30]
# backup = [10, 20, 30]

# %%
numbers = [10, 20, 30]

numbers.clear()

print(numbers)
# Out:
# []

# %%
sales = [52000,38000,71000,45000,63000,48000]

print(sum(sales))
print(max(sales))
print(min(sales))

print(len(sales))
# Out:
# 317000
# 71000
# 38000
# 6

# %%
student = "Rahul", 25, "Python"

print(student)
# Out:
# ('Rahul', 25, 'Python')

# %%
student = ("Rahul", 25, "Python")

name, age, course = student

print(name)
print(age)
print(course)
# Out:
# Rahul
# 25
# Python

# %%
order = ("ORD-501","Arjun","Monitor",2,32000)
print(order[2])

order_id, customer, product, qty, price = order

print(order_id, "-",customer, product, qty, price)

print(customer,qty,product,"worth",price)
# Out:
# Monitor
# ORD-501 - Arjun Monitor 2 32000
# Arjun 2 Monitor worth 32000

# %%
numbers = (10, 20, 30, 40, 50)
first, *middle, last = numbers

print(f"First: {first}, Middle: {middle}, Last: {last}")
# Out:
# First: 10, Middle: [20, 30, 40], Last: 50

# %%
invoice = ("INV-2024", "Priya", "Laptop", 85000)

print(invoice[0])

invoice[3] = 90000

print(invoice)
# Out:
# INV-2024
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 5
#       1 invoice = ("INV-2024", "Priya", "Laptop", 85000)
#       3 print(invoice[0])
# ----> 5 invoice[3] = 90000
#       7 print(invoice)
#
# TypeError: 'tuple' object does not support item assignment
